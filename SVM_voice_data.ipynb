# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudh-bukka/DataAnalysis-SupervisedML/blob/main/SVM_voice_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Ojas ML/Material/SVM/voice.csv")

# %% [markdown]
# # Attributes and correlation

# %%
df.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
# Checking for null values
df.isnull().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.shape
# Out:
# (3168, 21)

# %%
print("Total no. of people: ", df['label'].count(), '\n', df['label'].value_counts())
# Out:
# Total no. of people:  3168
#  male      1584
# female    1584
# Name: label, dtype: int64

# %% [markdown]
# # Splitting independent variables (features) and label

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
X
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
y
# Out:
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 3163    female
# 3164    female
# 3165    female
# 3166    female
# 3167    female
# Name: label, Length: 3168, dtype: object

# %% [markdown]
# ## Converting label into category or integers
# Can be done using LabelEncoder or One-hot Encoding.

# %%
# Using LabelEncoder

from sklearn.preprocessing import LabelEncoder

gender = LabelEncoder()
y = gender.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# ## Data Standardization
#
# Standardization refers to shifting the distribution of each attribute to have a mean of zero and a standard deviation of one (unit variance). It is useful to standardize attributes for a model. Standardization of datasets is a common requirement for many machine learning estimators implemented in scikit-learn; they might behave badly if the individual features do not more or less look like standard normally distributed data.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X = sc.fit_transform(X)
X
# Out:
# array([[-4.04924806,  0.4273553 , -4.22490077, ..., -1.43142165,
#         -1.41913712, -1.45477229],
#        [-3.84105325,  0.6116695 , -3.99929342, ..., -1.41810716,
#         -1.4058184 , -1.01410294],
#        [-3.46306647,  1.60384791, -4.09585052, ..., -1.42920257,
#         -1.41691733, -1.06534356],
#        ...,
#        [-1.29877326,  2.32272355, -0.05197279, ..., -0.5992661 ,
#         -0.58671739,  0.17588664],
#        [-1.2452018 ,  2.012196  , -0.01772849, ..., -0.41286326,
#         -0.40025537,  1.14916112],
#        [-0.51474626,  2.14765111, -0.07087873, ..., -1.27608595,
#         -1.2637521 ,  1.47567886]])

# %% [markdown]
# ## Split into train and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# # SVM

# %% [markdown]
# ## Running with default parameters

# %%
from sklearn.svm import SVC
from sklearn import metrics

# instantiate model
svc = SVC()
svc.fit(X_train, y_train)
y_svc_pred = svc.predict(X_test)
print("Accuracy score with default parameters: ", metrics.accuracy_score(y_test, y_svc_pred))
# Out:
# Accuracy score with default parameters:  0.9763406940063092

# %% [markdown]
# ## Running with default linear kernel

# %%
lin_svc = SVC(kernel = 'linear')
lin_svc.fit(X_train, y_train)

y_linsvc_pred = lin_svc.predict(X_test)
print("Accuracy score with linear kernel:", metrics.accuracy_score(y_test, y_linsvc_pred))
# Out:
# Accuracy score with linear kernel: 0.9779179810725552

# %% [markdown]
# ## Default polynomial
# Computes relationship between pairs of observations (from one group to another) WITHOUT actually changing the dimension. <br>
# <br>
# Formula: (a * b + r)^d <br> <br>
# a: value of one category <br>
# b: value of the other category <br>
# r: polynomial coefficient (Determined using Cross-validation) <br>
# d: degree of polynomial (Determined using Cross-validation)

# %%
svc_poly = SVC(kernel = 'poly')
svc_poly.fit(X_train, y_train)
y_polysvc_pred = svc_poly.predict(X_test)
print("Accuracy score with polynomial kernel:", metrics.accuracy_score(y_test, y_polysvc_pred))
# Out:
# Accuracy score with polynomial kernel: 0.9589905362776026

# %% [markdown]
# Accuracy using Polynomial kernel is LOW maybe because of over-fitting.

# %% [markdown]
# # Performing n-fold Cross Validation

# %%
# from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import cross_validate

# %%
scores = cross_validate(lin_svc, X, y, cv=10, scoring='accuracy') #cv is cross validation
print(scores)
# Out:
# {'fit_time': array([0.06306529, 0.05229354, 0.05059481, 0.0525775 , 0.04418755,
#        0.04937482, 0.04814386, 0.04783463, 0.04270744, 0.04758072]), 'score_time': array([0.00301528, 0.00198936, 0.00209427, 0.00199151, 0.00187922,
#        0.00218725, 0.00210071, 0.0019908 , 0.00197911, 0.00207186]), 'test_score': array([0.91167192, 0.97160883, 0.97160883, 0.97791798, 0.95899054,
#        0.9873817 , 0.99369085, 0.97791798, 0.95253165, 0.99367089])}

# %%
# print(scores.mean())
sum = 0
for i in scores.values():
  sum = sum + i
  print(i)

l = len(scores)

print(sum/l)
# Out:
# [0.06572175 0.07413459 0.06553531 0.0721972  0.0732305  0.07426357
#  0.07338333 0.0734272  0.06441927 0.07331681]
# [0.00553179 0.00589705 0.00553727 0.00571346 0.00574207 0.00652504
#  0.00604272 0.00610423 0.00562477 0.00605083]
# [0.89274448 0.94952681 0.93059937 0.92744479 0.94952681 0.99369085
#  0.98422713 0.96529968 0.87974684 0.9778481 ]
# [0.32133267 0.34318615 0.33389065 0.33511849 0.34283313 0.35815982
#  0.35455106 0.34827704 0.31659696 0.35240525]

# %%
scores = cross_validate(svc_poly, X, y, cv=10, scoring='accuracy') #cv is cross validation
print(scores)
# Out:
# {'fit_time': array([0.06734228, 0.07079291, 0.06559277, 0.07049632, 0.06545472,
#        0.08175945, 0.07139754, 0.07350302, 0.06541443, 0.07079887]), 'score_time': array([0.00537825, 0.00597692, 0.00559926, 0.00748301, 0.00578785,
#        0.00620699, 0.00646424, 0.00608253, 0.00562453, 0.0061872 ]), 'test_score': array([0.89274448, 0.94952681, 0.93059937, 0.92744479, 0.94952681,
#        0.99369085, 0.98422713, 0.96529968, 0.87974684, 0.9778481 ])}

# %%
sum = 0
for i in scores.values():
  sum = sum + i
  print(i)

l = len(scores)

print(sum/l)
# Out:
# [0.06734228 0.07079291 0.06559277 0.07049632 0.06545472 0.08175945
#  0.07139754 0.07350302 0.06541443 0.07079887]
# [0.00537825 0.00597692 0.00559926 0.00748301 0.00578785 0.00620699
#  0.00646424 0.00608253 0.00562453 0.0061872 ]
# [0.89274448 0.94952681 0.93059937 0.92744479 0.94952681 0.99369085
#  0.98422713 0.96529968 0.87974684 0.9778481 ]
# [0.32182167 0.34209888 0.33393047 0.33514137 0.34025646 0.36055243
#  0.35402964 0.34829508 0.3169286  0.35161139]
